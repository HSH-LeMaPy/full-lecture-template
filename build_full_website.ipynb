# %%
quarto render # das ist das Profil skript. Ggf --no-clean anfügen damit der outputordner nicht erst geleert wird.

# %%
quarto render --profile pdfs

# %%
quarto render --profile notebooks

# %%
quarto render --profile folien

# %%
quarto render --profile cheatsheet

# %%
quarto render --profile aufgaben
